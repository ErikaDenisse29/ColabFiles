# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikaDenisse29/ColabFiles/blob/main/ProyectoProgADAP_256027NvaVersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto de Programación para Analítica Descriptiva y Predictiva**
# ## Nombre del Proyecto:
# Detección de ataques al corazón.
# ## Grupo: A
# ## Autor:
# Erika Denisse Montanez Valdivia
# ## Matrícula:
# 256027
# ## Fecha:
# 04 de abril de 2025

# %% [markdown]
# # **1. Introducción**
#
# ## **- Descripción del problema:**
#
# Un ataque al corazón, también conocido como infarto de miocardio, es una emergencia médica que ocurre cuando se bloquea el flujo de sangre al corazón. Esto priva al corazón de oxígeno y puede causar la muerte de las células cardíacas.
# Identificar los factores de riesgo asociados a los ataques al corazón para predecir la probabilidad de que un paciente sufra un ataque. Esto implica analizar variables como la edad, el genero, el estilo de vida (tabaquismo,actividad fisica, consumo de alcohol), las condiciones medicas (hipertension, colesterol, etc).
#
#
#
# ## - Objetivo del análisis: ¿Qué impacto tendrá este análisis?
# Este conjunto de datos proporciona un conjunto equilibrado y diverso de características para ayudar a los investigadores, científicos de datos y profesionales del aprendizaje automático a explorar métodos para predecir los riesgos de ataque cardíaco.
#
# ## - Fuente de datos: https://www.kaggle.com/code/oguzhanshn/heart-attack-presicion-models/notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')

df = pd.read_excel("drive/MyDrive/campos_heart.xlsx") #dtype=str
print("Informacion de los campos:")
display(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Informacion de los campos:
#                       Campo  \
# 0                       Age
# 1                    Gender
# 2                   Smoking
# 3       Alcohol_Consumption
# 4   Physical_Activity_Level
# 5                       BMI
# 6                  Diabetes
# 7              Hypertension
# 8         Cholesterol_Level
# 9                Resting_BP
# 10               Heart_Rate
# 11           Family_History
# 12             Stress_Level
# 13          Chest_Pain_Type
# 14              Thalassemia
# 15      Fasting_Blood_Sugar
# 16              ECG_Results
# 17  Exercise_Induced_Angina
# 18  Max_Heart_Rate_Achieved
# 19        Heart_Attack_Risk
#
#                                           Descripcion             Tipo dato
# 0                Age of the individual (18–90 years).     Numeric (Integer)
# ...

# %% [markdown]
# # **2. Información General del Conjunto de Datos**
#
# ## - Explicación de la fuente de datos:
#
# - **Descripción de la temática o área a la que pertenece el conjunto de datos, año,**
#
# El conjunto de datos pertenece al área de salud pública y medicina, específicamente relacionado con la salud cardiovascular y factores de riesgo asociados, y está diseñado para evaluar el riesgo de enfermedades cardiovasculares en una población. Esto incluye la identificación de factores de riesgo que pueden contribuir a problemas de salud como ataques cardíacos, hipertensión y diabetes.
# - **Fuente de la base de datos, incluyendo el link**
#
# https://www.kaggle.com/code/oguzhanshn/heart-attack-presicion-models/notebook
#
#  Tamaño: El dataset cuenta con 50,000 datos, lo que considero suficientes para un análisis estadístico.
#
#   Representatividad: El dataset incluye 20 características que capturan diversos atributos demográficos, clínicos, de estilo de vida y de diagnóstico.
#
#   Calidad: Los datos estan  limpios, sin valores faltantes.
#
#   Las variables mas relevantes son:
#
#   Edad: El riesgo aumenta con la edad.
#
#   Género: Los hombres suelen tener un riesgo más alto.
#
#  Tabaquismo: Fumar es un factor de riesgo importante.
#
#   Hipertensión y colesterol: Ambas están directamente relacionadas con enfermedades cardiovasculares.
#
#   Diabetes: Aumenta el riesgo de problemas cardíacos.
#
#   BMI: Un índice de masa corporal alto puede indicar obesidad, un factor de riesgo.
#
#   Nivel de actividad física: La falta de ejercicio aumenta el riesgo.
#
#
# - **Formato del Archivo (Txt, CSV, etc)**
#
# Tipo: El dataset es un archivo .csv
#
# - **Para qué se ha usado o se usa.**
#
# Puede ser usado para ayudar a los investigadores, científicos de datos y profesionales del aprendizaje automático a explorar métodos para predecir los riesgos de ataque cardíaco.
#
# ## - Explicación sobre problemas en la carga de Datos y el Código para la carga de datos desde archivos (bibiotecas, etc.)
# Se usara las siguientes bibiotecas:
#
#
# *   Pandas para la manipulacion y analisis de datos
# *   Numpy para el calculo numerico
# *   Seaborn para crear graficos estadisticos
# *   Matplotlib crear visualizaciones estáticas, interactivas y animadas

# %%
df = pd.read_csv("drive/MyDrive/heart_attack_risk_dataset.csv", low_memory=False) #dtype=str
#print(df.head())

print("Datos del archivo de deteccion de ataques:")
display(df)
# Out:
# Datos del archivo de deteccion de ataques:
#        Age  Gender  Smoking  Alcohol_Consumption Physical_Activity_Level  \
# 0       69  Female        1                    0                Moderate
# 1       32    Male        0                    0                Moderate
# 2       89    Male        0                    1                Moderate
# 3       78    Male        0                    1                Moderate
# 4       38  Female        1                    0                Moderate
# ...    ...     ...      ...                  ...                     ...
# 49995   21    Male        0                    0                     Low
# 49996   35  Female        0                    0                     Low
# 49997   46    Male        0                    1                    High
# 49998   56    Male        0                    1                     Low
# 49999   72    Male        0                    0                    High
#
# ...

# %% [markdown]
# #**3.Descripción del Conjunto de Datos**
#
# ## - Deberás escribir el número de filas, columnas
# ## - Tipos de datos de las columnas
# ##- Nombres de las columnas
# ##- Descripción estadística de cada una de las columnas

# %%
print(f"El DataFrame tiene {df.shape[0]} filas y {df.shape[1]} columnas.")
print()

print("Tipos de datos de las columnas, y nombres de las columnas:\n")
print(df.info())
print()

print("Descripción estadística de cada una de las columnas:\n")
descripcion = df.describe()
print(descripcion)
# Out:
# El DataFrame tiene 50000 filas y 20 columnas.
#
# Tipos de datos de las columnas, y nombres de las columnas:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      50000 non-null  int64
#  1   Gender                   50000 non-null  object
#  2   Smoking                  50000 non-null  int64
#  3   Alcohol_Consumption      50000 non-null  int64
#  4   Physical_Activity_Level  50000 non-null  object
#  5   BMI                      50000 non-null  float64
#  6   Diabetes                 50000 non-null  int64
#  7   Hypertension             50000 non-null  int64
#  8   Cholesterol_Level        50000 non-null  float64
#  9   Resting_BP               50000 non-null  int64
#  10  Heart_Rate               50000 non-null  int64
#  11  Family_History           50000 non-null  int64
# ...

# %% [markdown]
# # **4. Limpieza y Transformación del Conjunto de Datos**
#
#  **Normalización de Nombres de Columnas:**
#
# En este dataset algunos títulos utilizan mayúsculas al inicio de cada palabra, mientras que otros tienen guiones bajos. Se cambiará todo a minúsculas y si hay espacios se cambiaran a guiones bajos (_).
#
# Algunos títulos son largos, como Exercise_Induced_Angina y Heart_Attack_Risk. Se van a abreviar para facilitar su uso, pero asegurándome de que sigan siendo comprensibles.
#
# Considero que todos los demás títulos son descriptivos y no requiere más cambios.

# %%
print("Nombres de columnas originales:\n")
print(df.columns)
print()

df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('exercise_induced_angina', 'ex_angina')
df.columns = df.columns.str.replace('heart_attack_risk', 'heart_risk')
df.columns = df.columns.str.replace('max_heart_rate_achieved', 'max_heart_rate')
df.columns = df.columns.str.replace('alcohol_consumption', 'alc_cons')
df.columns = df.columns.str.replace('physical_activity_level', 'phy_act_lvl')
df.columns = df.columns.str.replace('cholesterol_level', 'cholesterol_lvl')

print("Nombres de columnas normalizados:\n")
print(df.columns)
# Out:
# Nombres de columnas originales:
#
# Index(['Age', 'Gender', 'Smoking', 'Alcohol_Consumption',
#        'Physical_Activity_Level', 'BMI', 'Diabetes', 'Hypertension',
#        'Cholesterol_Level', 'Resting_BP', 'Heart_Rate', 'Family_History',
#        'Stress_Level', 'Chest_Pain_Type', 'Thalassemia', 'Fasting_Blood_Sugar',
#        'ECG_Results', 'Exercise_Induced_Angina', 'Max_Heart_Rate_Achieved',
#        'Heart_Attack_Risk'],
#       dtype='object')
#
# Nombres de columnas normalizados:
#
# Index(['age', 'gender', 'smoking', 'alc_cons', 'phy_act_lvl', 'bmi',
#        'diabetes', 'hypertension', 'cholesterol_lvl', 'resting_bp',
#        'heart_rate', 'family_history', 'stress_level', 'chest_pain_type',
#        'thalassemia', 'fasting_blood_sugar', 'ecg_results', 'ex_angina',
#        'max_heart_rate', 'heart_risk'],
#       dtype='object')

# %% [markdown]
# **Corrección de Tipos de Datos:**
#
# Analizando cada uno de los campos del dataset:
#
# Se mantienen como tipo int64:
#
# *   age
# *   smoking
# *   alc_cons
# *   diabetes
# *   hypertension
# *   resting_bp
# *   heart_rate
# *   family_history
# *   fasting_blood_sugar
# *   ex_angina
# *   max_heart_rate
#
# La mayoría de estos campos representan un estado binario (1 o 0)
#
# Se mantienen como tipo Float64:
# * bmi
# * cholesterol_level
#
# Los que cambian son los que dicen tipo Object:
#
#
# *   gender
# *   phy_act_lvl
# *   stress_level
# *   chest_pain_type
# *   thalassemia
# *   ecg_results
# *   heart_risk
#
# Esto es porque es mejor usar el tipo category para datos categóricos con un número limitado de valores únicos, ya que esto mejora el rendimiento y reduce el uso de memoria.

# %%
print("Tipos de datos originales:\n")
print(df.dtypes)
print()

df['gender'] = df['gender'].astype('category')
df['phy_act_lvl'] = df['phy_act_lvl'].astype('category')
df['stress_level'] = df['stress_level'].astype('category')
df['chest_pain_type'] = df['chest_pain_type'].astype('category')
df['thalassemia'] = df['thalassemia'].astype('category')
df['ecg_results'] = df['ecg_results'].astype('category')
df['heart_risk'] = df['heart_risk'].astype('category')

print("Tipos de datos cambiados:\n")
print(df.dtypes)
# Out:
# Tipos de datos originales:
#
# age                      int64
# gender                  object
# smoking                  int64
# alc_cons                 int64
# phy_act_lvl             object
# bmi                    float64
# diabetes                 int64
# hypertension             int64
# cholesterol_lvl        float64
# resting_bp               int64
# heart_rate               int64
# family_history           int64
# stress_level            object
# chest_pain_type         object
# thalassemia             object
# fasting_blood_sugar      int64
# ecg_results             object
# ex_angina                int64
# max_heart_rate           int64
# heart_risk              object
# dtype: object
#
# Tipos de datos cambiados:
#
# age                       int64
# gender                 category
# smoking                   int64
# alc_cons                  int64
# phy_act_lvl            category
# bmi                     float64
# diabetes                  int64
# ...

# %% [markdown]
# # **Limpieza, Transformación y Normalización de Datos Categóricos:**

# %% [markdown]
# Verificar valores únicos por columna categórica.

# %%
for col in ['gender', 'phy_act_lvl', 'stress_level', 'chest_pain_type', 'thalassemia', 'ecg_results', 'heart_risk']:
    print(f"Valores únicos en la columna '{col}':")
    print(df[col].unique())
    print()

for col in ['gender', 'phy_act_lvl', 'stress_level', 'chest_pain_type', 'thalassemia', 'ecg_results', 'heart_risk']:
    print(f"Valores únicos en la columna '{col}':")
    print(df[col].value_counts())
    print()
# Out:
# Valores únicos en la columna 'gender':
# ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']
#
# Valores únicos en la columna 'phy_act_lvl':
# ['Moderate', 'Low', 'High']
# Categories (3, object): ['High', 'Low', 'Moderate']
#
# Valores únicos en la columna 'stress_level':
# ['Moderate', 'Low', 'High']
# Categories (3, object): ['High', 'Low', 'Moderate']
#
# Valores únicos en la columna 'chest_pain_type':
# ['Non-anginal', 'Asymptomatic', 'Typical', 'Atypical']
# Categories (4, object): ['Asymptomatic', 'Atypical', 'Non-anginal', 'Typical']
#
# Valores únicos en la columna 'thalassemia':
# ['Reversible defect', 'Normal', 'Fixed defect']
# Categories (3, object): ['Fixed defect', 'Normal', 'Reversible defect']
#
# Valores únicos en la columna 'ecg_results':
# ['Normal', 'ST-T abnormality', 'Left Ventricular Hypertrophy']
# Categories (3, object): ['Left Ventricular Hypertrophy', 'Normal', 'ST-T abnormality']
#
# Valores únicos en la columna 'heart_risk':
# ...

# %% [markdown]
# Para limpiar los datos categoricos se va a:
#
# 1.   Eliminar  duplicados
# 2.   Manejar valores nulos (si hubiera)
# 3.   Convertir a minusculas

# %%
print("DataFrame antes de la limpieza:\n")
print(df)

df = df.drop_duplicates()
#df.fillna('Desconocido', inplace=True)

for col in ['gender', 'phy_act_lvl', 'stress_level', 'chest_pain_type', 'thalassemia', 'ecg_results', 'heart_risk']:
    if df[col].dtype.name == 'category':
        df[col] = df[col].cat.add_categories(['Desconocido'])

# Now fill NaN values with 'Desconocido'
df.fillna('Desconocido', inplace=True)

df['gender'] = df['gender'].str.lower()
df['phy_act_lvl'] = df['phy_act_lvl'].str.lower()
df['stress_level'] = df['stress_level'].str.lower()
df['chest_pain_type'] = df['chest_pain_type'].str.lower()
df['thalassemia'] = df['thalassemia'].str.lower()
df['ecg_results'] = df['ecg_results'].str.lower()
df['heart_risk'] = df['heart_risk'].str.lower()

print()
print("DataFrame después de la limpieza:\n")
print(df)
# Out:
# DataFrame antes de la limpieza:
#
#        age  gender  smoking  alc_cons phy_act_lvl    bmi  diabetes  \
# 0       69  Female        1         0    Moderate  34.61         1
# 1       32    Male        0         0    Moderate  22.75         0
# 2       89    Male        0         1    Moderate  35.32         0
# 3       78    Male        0         1    Moderate  18.23         1
# 4       38  Female        1         0    Moderate  19.82         0
# ...    ...     ...      ...       ...         ...    ...       ...
# 49995   21    Male        0         0         Low  39.93         0
# 49996   35  Female        0         0         Low  18.10         0
# 49997   46    Male        0         1        High  21.42         0
# 49998   56    Male        0         1         Low  29.93         0
# 49999   72    Male        0         0        High  30.85         0
#
#        hypertension  cholesterol_lvl  resting_bp  heart_rate  family_history  \
# ...

# %% [markdown]
# **Revisar alta cardinalidad**
#
# Se revisa si en los datos categoricos no hay alta cardinalidad

# %%
category_df = df.select_dtypes(include='category')

cardinalidad = category_df.nunique()
umbral_alta_cardinalidad = 10  #más de 10 valores únicos

alta_cardinalidad = cardinalidad[cardinalidad > umbral_alta_cardinalidad]

print("Cardinalidad de cada columna:")
print(cardinalidad)

print("\nColumnas con alta cardinalidad:")
print(alta_cardinalidad)
# Out:
# Cardinalidad de cada columna:
# Series([], dtype: float64)
#
# Columnas con alta cardinalidad:
# Series([], dtype: float64)

# %% [markdown]
# # **Datos Perdidos:**
#
# El dataset no tiene datos perdidos.

# %%
missing_data = df.isnull().sum()
print("Datos perdidos por columna:")
print(missing_data)

has_missing = df.isna().any().any()
print("\n¿Hay datos perdidos en el DataFrame?", has_missing)
# Out:
# Datos perdidos por columna:
# age                    0
# gender                 0
# smoking                0
# alc_cons               0
# phy_act_lvl            0
# bmi                    0
# diabetes               0
# hypertension           0
# cholesterol_lvl        0
# resting_bp             0
# heart_rate             0
# family_history         0
# stress_level           0
# chest_pain_type        0
# thalassemia            0
# fasting_blood_sugar    0
# ecg_results            0
# ex_angina              0
# max_heart_rate         0
# heart_risk             0
# dtype: int64
#
# ¿Hay datos perdidos en el DataFrame? False

# %% [markdown]
# ## **Limpieza, Transformación y Normalización de Datos Temporales:**
#
# El dataset no tiene datos temporales.

# %% [markdown]
# ##**Outliers:**
#
# Para revisar si el dataset contaba con outliers realice lo siguiente:
#
# Descripción estadística de los datos - numérica: desviación estándar
#
# Es posible detectar aquellos datos atípicos usando la desviación estándar.
#
# Si Valori>(3×std) entonces es un valor atípico. Se usa describe para mostrar la desviación estándar por columna. Finalmente, muestro los valores que cumplen con dicha regla.
# En este caso no salieron datos atípicos.

# %%
print("Descripción estadística de cada una de las columnas:\n")
descripcion = df.describe()
print(descripcion)


numerical_df = df.select_dtypes(include=np.number)


print('\nDesviación estándar por columna ')
print(numerical_df.std())


atipicos = df[(np.abs(numerical_df - numerical_df.mean()) > (3 * numerical_df.std())).any(axis=1)]

print('\nValores atípicos por columna ')
print(atipicos)
# Out:
# Descripción estadística de cada una de las columnas:
#
#                 age       smoking      alc_cons           bmi      diabetes  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean      53.398700      0.298420      0.401980     27.519357      0.198840
# std       20.799006      0.457569      0.490303      7.225176      0.399131
# min       18.000000      0.000000      0.000000     15.000000      0.000000
# 25%       35.000000      0.000000      0.000000     21.270000      0.000000
# 50%       53.000000      0.000000      0.000000     27.540000      0.000000
# 75%       71.000000      1.000000      1.000000     33.770000      0.000000
# max       89.000000      1.000000      1.000000     40.000000      1.000000
#
#        hypertension  cholesterol_lvl    resting_bp    heart_rate  \
# count   50000.00000     50000.000000  50000.000000  50000.000000
# mean        0.29738       225.036444    134.434100     94.530480
# ...

# %% [markdown]
# # **5. Análisis Exploratorio de los Datos**
#
# ## - Preguntas a responder
# ## - Estadísticas Empleadas, visualización y Resumen de las respuestas encontradas.

# %% [markdown]
# 1- ¿Cuál es la distribución de la edad en la población estudiada?
#
# Los individuos se encuentran en el rango de 19 a 90 años.

# %%
def medidas_tendencia_central(df):
    media = df[['age', 'bmi']].mean()
    mediana = df[['age', 'bmi']].median()
    moda = df[['age', 'bmi']].mode().iloc[0]
    return media, mediana, moda

media, mediana, moda = medidas_tendencia_central(df)
print("Medidas de Tendencia Central:")
print("Media:\n", media)
print("Mediana:\n", mediana)
print("Moda:\n", moda)
# Out:
# Medidas de Tendencia Central:
# Media:
#  age    53.398700
# bmi    27.519357
# dtype: float64
# Mediana:
#  age    53.00
# bmi    27.54
# dtype: float64
# Moda:
#  age    75.00
# bmi    16.06
# Name: 0, dtype: float64

# %%
# 1. Distribución de la Edad
plt.figure(figsize=(10, 5))
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Distribución de la Edad')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.axvline(df['age'].mean(), color='r', linestyle='--', label='Media')
plt.legend()
plt.show()

# %% [markdown]
# 1.1 Conteo de fumadores por edades y edad con mas fumadores

# %%
fumadores = df[df['smoking'] == 1]
edad_fumadores = fumadores['age'].value_counts().reset_index()
edad_fumadores.columns = ['age', 'count']
print("Conteo de Fumadores por Edad:\n", edad_fumadores)


max_age = edad_fumadores.loc[edad_fumadores['count'].idxmax()]
print()
print(f"La edad que fuma más es: {max_age['age']} con {max_age['count']} fumadores.")


sns.set(style="whitegrid")

plt.figure(figsize=(15, 6))
sns.barplot(data=edad_fumadores, x='age', y='count', palette='Set2')

plt.title('Conteo de Fumadores por Edad')
plt.xlabel('Edad')
plt.ylabel('Conteo de Fumadores')
plt.xticks(rotation=45)
plt.show()
# Out:
# Conteo de Fumadores por Edad:
#      age  count
# 0    19    239
# 1    27    235
# 2    26    233
# 3    71    230
# 4    45    230
# ..  ...    ...
# 67   52    185
# 68   48    183
# 69   89    181
# 70   44    180
# 71   67    165
#
# [72 rows x 2 columns]
#
# La edad que fuma más es: 19 con 239 fumadores.
# <ipython-input-28-c1fadb68b90c>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=edad_fumadores, x='age', y='count', palette='Set2')

# %% [markdown]
# 1.2 Conteo de individuos con diabetes por edades y edad con mas casos de diabetes

# %%
diabetes_ = df[df['diabetes'] == 1]

diabetes_counts = diabetes_['age'].value_counts().reset_index()
diabetes_counts.columns = ['age', 'count']
print("Conteo de diabetes por Edad:\n", diabetes_counts)

max_diabetes = diabetes_counts.loc[diabetes_counts['count'].idxmax()]
print(f"La edad que tiene más diabetes es: {max_diabetes['age']} con {max_diabetes['count']} con diabetes.")

sns.set(style="whitegrid")

plt.figure(figsize=(15, 6))
sns.barplot(data=diabetes_counts, x='age', y='count', palette='Set2')

plt.title('Conteo de diabetes por Edad')
plt.xlabel('Edad')
plt.ylabel('Conteo de Fumadores')
plt.xticks(rotation=45)  # Alinear etiquetas en el eje x
plt.show()
# Out:
# Conteo de diabetes por Edad:
#      age  count
# 0    45    164
# 1    75    162
# 2    67    159
# 3    24    158
# 4    89    157
# ..  ...    ...
# 67   70    121
# 68   57    120
# 69   72    118
# 70   74    117
# 71   48    112
#
# [72 rows x 2 columns]
# La edad que tiene más diabetes es: 45 con 164 con diabetes.
# <ipython-input-29-294dae28b391>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=diabetes_counts, x='age', y='count', palette='Set2')

# %% [markdown]
# 2- ¿Cómo se distribuyen los géneros en el dataset?
#
# La proporción de hombres y mujeres es aproximadamente 50/50, con ligeras variaciones

# %%
# 2. Distribución de Géneros
plt.figure(figsize=(10, 5))
sns.countplot(x='gender', data=df)
plt.title('Distribución de Géneros')
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# 1.2 Comparar numero de fumadores entre generos.
#
# La grafica muestra datos similares sin una diferencia significativa

# %%
prom_fumador = df.groupby(['gender', 'smoking']).size().unstack(fill_value=0)
prom_smoking_percentage = prom_fumador.div(prom_fumador.sum(axis=1), axis=0) * 100

print("Promedio de Fumadores por Género:\n", prom_smoking_percentage)

sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))
prom_smoking_percentage.plot(kind='bar', color=['lightblue', 'salmon'])

plt.title('Promedio de Fumadores por Género')

plt.ylabel('Porcentaje de Fumadores (%)')
plt.xticks(rotation=0)
plt.ylim(0, 100)
plt.legend(title='Fumador', labels=['No', 'Sí'])
plt.show()
# Out:
# Promedio de Fumadores por Género:
#  smoking          0          1
# gender
# female   70.489516  29.510484
# male     69.824195  30.175805

# %% [markdown]
# 1.3 Comparar numero de consumidores de alcohol entre generos.
#
# La grafica muestra datos similares sin una diferencia significativa

# %%
promedio_al = df.groupby(['gender', 'alc_cons']).size().unstack(fill_value=0)

promedio_al_percentage = promedio_al.div(promedio_al.sum(axis=1), axis=0) * 100
print("Promedio de consumo de alcohol por Género:\n", promedio_al_percentage)

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
promedio_al_percentage.plot(kind='bar', color=['lightblue', 'salmon'])

plt.title('Promedio de consumo de alcohol por Género')
plt.xlabel('Género')
plt.ylabel('Porcentaje de consumo(%)')
plt.xticks(rotation=0)
plt.ylim(0, 100)
plt.legend(title='Consumo', labels=['No', 'Sí'])
plt.show()
# Out:
# Promedio de consumo de alcohol por Género:
#  alc_cons          0          1
# gender
# female    59.666746  40.333254
# male      59.938187  40.061813

# %% [markdown]
# 1.4 Comparar actividad fisica entre generos.
#
# La grafica muestra datos similares sin una diferencia significativa

# %%
activity_counts = df.groupby(['gender', 'phy_act_lvl']).size().reset_index(name='count')
print("Conteo de Género y Niveles de Actividad Física:\n", activity_counts)

sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
sns.barplot(data=activity_counts, x='gender', y='count', hue='phy_act_lvl', palette='Set2')

plt.title('Conteo de Género y Niveles de Actividad Física')
plt.xlabel('Género')
plt.ylabel('Conteo')
plt.legend(title='Nivel de Actividad Física')
plt.xticks(rotation=0)
plt.show()
# Out:
# Conteo de Género y Niveles de Actividad Física:
#     gender phy_act_lvl  count
# 0  female        high   5112
# 1  female         low  10049
# 2  female    moderate   9925
# 3    male        high   4833
# 4    male         low  10012
# 5    male    moderate  10069

# %% [markdown]
# 3- ¿Existen diferencias significativas en el riesgo de ataque cardíaco entre géneros?
#
# En este dataset no hay diferencias significativas

# %%
  # 3. Distribución de riesgo de ataque cardíaco entre géneros
sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='gender', hue='heart_risk')
plt.title('Incidencia de Ataques Cardíacos por Género')
plt.xlabel('Género')
plt.ylabel('Número de Casos')
# Out:
# Text(0, 0.5, 'Número de Casos')

# %% [markdown]
# 4- ¿Cuál es la relación entre el consumo de alcohol y el riesgo de ataque al corazón?
#
# No hay una asociación significativa entre el estado de fumar y el riesgo de ataque al corazón.

# %%
#4. Relación entre Consumo de Alcohol y Riesgo de Ataque al Corazón
plt.figure(figsize=(10, 5))
sns.countplot(x='alc_cons', hue='heart_risk', data=df)
plt.title('Consumo de Alcohol vs Riesgo de Ataque al Corazón')
plt.xlabel('Consumo de Alcohol (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.legend(title='Riesgo de Ataque al Corazón')
plt.show()

# %% [markdown]
# 5- ¿Cuál es la relación entre el tabaquismo y la incidencia de ataques cardíacos?
#
# No hay una asociación significativa entre el estado de fumar y el riesgo de ataque al corazón.
# La grafica podria parecer indicar que los casos en cero tienen mas riesgo, pero esto es porque hay el doble de individuos no fumadores que si fumadores

# %%
    #5. Comparar incidencia entre fumadores y no fumadores
    plt.figure(figsize=(10, 5))
    sns.countplot(data=df, x='smoking', hue='heart_risk')
    plt.title('Incidencia de Ataques Cardíacos por Tabaquismo')
    plt.xlabel('Tabaquismo')
    plt.ylabel('Número de Casos')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 5.1 Revisar total de fumadores vs no fumadores

# %%
# Contar la frecuencia de fumadores y no fumadores
smoking_counts = df['smoking'].value_counts()

# Mostrar los conteos
print(smoking_counts)

# Visualizar los resultados
plt.figure(figsize=(8, 5))
sns.barplot(x=smoking_counts.index, y=smoking_counts.values)
plt.title('Comparación entre Fumadores y No Fumadores')
plt.xlabel('Estado de Fumar (0 = No Fumador, 1 = Fumador)')
plt.ylabel('Número de Individuos')
plt.xticks(ticks=[0, 1], labels=['No Fumador', 'Fumador'])
plt.show()

# Comparar si hay más fumadores que no fumadores
if smoking_counts.get(1, 0) > smoking_counts.get(0, 0):
    print("Hay más individuos que son fumadores que no fumadores.")
else:
    print("Hay más individuos que no son fumadores que fumadores.")
# Out:
# smoking
# 0    35079
# 1    14921
# Name: count, dtype: int64
# Hay más individuos que no son fumadores que fumadores.

# %% [markdown]
# 6 ¿Cómo afecta el nivel de actividad física al riesgo de ataque al corazón?
#
# Los individuos con actividad física alta tienen un menor riesgo de ataque al corazón en comparación con aquellos con actividad baja

# %%
# 6. Efecto del Nivel de Actividad Física
plt.figure(figsize=(10, 6))
sns.countplot(x='phy_act_lvl', hue='heart_risk', data=df)
plt.title('Nivel de Actividad Física vs Riesgo de Ataque al Corazón')
plt.xlabel('Nivel de Actividad Física')
plt.ylabel('Frecuencia')
plt.legend(title='Riesgo de Ataque al Corazón')
plt.show()

# %% [markdown]
# 7. Cual es la prevalencia de diabetes
#
# La proporción de ataques cardíacos en diabéticos es 0.20, lo que significa que el 20% de los individuos con diabetes en el dataset han experimentado un ataque cardíaco.

# %%
# 7 Calcular la prevalencia de diabetes
diabetes_prevalence = df['diabetes'].mean() * 100
print(f"\nPrevalencia de Diabetes: {diabetes_prevalence:.2f}%")


diabetes_attack_counts = df.groupby(['diabetes', 'heart_risk']).size().unstack()
print("\nConteo de ataques cardíacos por diabetes:\n", diabetes_attack_counts)


diabetes_attack_ratio = diabetes_attack_counts.loc[1, 'high'] / diabetes_attack_counts.loc[1].sum()
print(f"\nProporción de ataques cardíacos en diabéticos: {diabetes_attack_ratio:.2f}")
# Out:
# Prevalencia de Diabetes: 19.88%
#
# Conteo de ataques cardíacos por diabetes:
#  heart_risk  high    low  moderate
# diabetes
# 0           8060  20115     11883
# 1           2012   4909      3021
#
# Proporción de ataques cardíacos en diabéticos: 0.20

# %% [markdown]
# 8. ¿Cómo se distribuyen los tipos de dolor en el pecho en relación con el riesgo de ataque al corazón?
#
# No hay una asociación significativa entre los dolores en el pecho y el riesgo de ataque al corazón.

# %%
#  8 Distribución de Tipos de Dolor en el Pecho
plt.figure(figsize=(10, 6))
sns.countplot(x='chest_pain_type', hue='heart_risk', data=df)
plt.title('Tipos de Dolor en el Pecho vs Riesgo de Ataque al Corazón')
plt.xlabel('Tipo de Dolor en el Pecho')
plt.ylabel('Frecuencia')
plt.legend(title='Riesgo de Ataque al Corazón')
plt.show()

# %% [markdown]
# 9. Cuál es la relacion entre el BMI y los ataques al corazon
# 10. Cuál es la relacion entre Hipertensión y Colesterol
#
# Los datos no muestran una relacion significativa en los riesgos de ataque al corazon

# %%
sns.set(style="whitegrid")

def diagramas_dispersion(df):
    plt.figure(figsize=(12, 5))

    # Relación entre BMI y riesgo de ataque cardíaco
    plt.subplot(1, 2, 1)
    sns.scatterplot(data=df, x='bmi', y='heart_risk', hue='gender', alpha=0.7)
    plt.title('Relación entre BMI y Riesgo de Ataque Cardíaco')
    plt.xlabel('BMI')
    plt.ylabel('Riesgo de Ataque')

    # Relación entre hipertensión y colesterol
    plt.subplot(1, 2, 2)
    sns.scatterplot(data=df, x='hypertension', y='cholesterol_lvl', hue='heart_risk', alpha=0.7)
    plt.title('Relación entre Hipertensión y Colesterol')
    plt.xlabel('Hipertensión')
    plt.ylabel('Colesterol')

    plt.tight_layout()
    plt.show()

diagramas_dispersion(df)

# %% [markdown]
# 11.  No hay correlación. No hay relación lineal entre las variables numericas

# %%
def calcular_correlacion(df):

    correlacion = numerical_df.corr(method='pearson')
    return correlacion


def visualizar_correlacion(correlacion):
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlacion, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
    plt.title('Matriz de Correlación')
    plt.show()

correlacion = calcular_correlacion(df)
visualizar_correlacion(correlacion)

# %% [markdown]
# 12. Cuál es la relación entre nivel de colesterol y edad
#
# No se ve una relación directa

# %%
# Gráfico de dispersión de Cholesterol Level vs. Age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='cholesterol_lvl', hue='heart_risk', data=df, palette='viridis', alpha=0.7)
plt.title('Nivel de Colesterol vs. Edad')
plt.xlabel('Edad')
plt.ylabel('Nivel de Colesterol (mg/dL)')
plt.legend(title='Riesgo de Ataque al Corazón')
plt.show()

# %% [markdown]
# 13. Cuál es la relación entre nivel de hipertensión y ataques
# 14. Cuál es la relación entre nivel de colesterol y ataques

# %%
# Visualizar la relación entre hipertensión y ataques cardíacos
plt.figure(figsize=(10, 5))
sns.countplot(x='hypertension', hue='heart_risk', data=df, palette='pastel')
plt.title('Relación entre Hipertensión y Ataques Cardíacos')
plt.xlabel('Hipertensión (0: No, 1: Sí)')
plt.ylabel('Número de Individuos')
plt.legend(title='Ataque Cardíaco', labels=['No', 'Sí'])
plt.show()

# Visualizar la relación entre colesterol y ataques cardíacos
plt.figure(figsize=(10, 5))
sns.boxplot(x='heart_risk', y='cholesterol_lvl', data=df, palette='pastel')
plt.title('Niveles de Colesterol por Ataque Cardíaco')
plt.xlabel('Ataque Cardíaco (0: No, 1: Sí)')
plt.ylabel('Colesterol')
plt.show()
# Out:
# <ipython-input-89-9385969fc49c>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='heart_risk', y='cholesterol_lvl', data=df, palette='pastel')

# %% [markdown]
# 15.  Comparación de Fumar y actividad fisica

# %%
comparison_counts = df.groupby(['smoking', 'diabetes', 'phy_act_lvl']).size().reset_index(name='count')
print("Conteo de Fumar, y actividad fisica:\n", comparison_counts)


sns.set(style="whitegrid")

plt.figure(figsize=(12, 8))
sns.barplot(data=comparison_counts, x='smoking', y='count', hue='phy_act_lvl', palette='Set2')

plt.title('Comparación de Fumar y actividad fisica')
plt.xlabel('Fumar')
plt.ylabel('Conteo')
plt.legend(title='phy_act_lvl')
plt.xticks(rotation=0)
plt.show()
# Out:
# Conteo de Fumar, y actividad fisica:
#      smoking  diabetes phy_act_lvl  count
# 0         0         0        high   5642
# 1         0         0         low  11229
# 2         0         0    moderate  11204
# 3         0         1        high   1399
# 4         0         1         low   2844
# 5         0         1    moderate   2761
# 6         1         0        high   2357
# 7         1         0         low   4805
# 8         1         0    moderate   4821
# 9         1         1        high    547
# 10        1         1         low   1183
# 11        1         1    moderate   1208

# %% [markdown]
# 16. Revisar casos de solo mujeres en un rango de edad de 30 a 40 con diabetes e hipertensión
#
# Hay mas casos de hipertensión que diabetes en ese rango de edad

# %%
filt_df = df[(df['gender'] == 'female') & (df['age'] >= 30) & (df['age'] <= 40)]

diabetes_count = filt_df['diabetes'].value_counts()
hypertension_count = filt_df['hypertension'].value_counts()

labels = ['No Diabetes', 'Diabetes']
diabetes_values = [diabetes_count.get(0, 0), diabetes_count.get(1, 0)]

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.bar(labels, diabetes_values, color=['blue', 'red'])
plt.title('Diabetes en Mujeres de 30 a 40 Años')
plt.ylabel('Cantidad')
plt.ylim(0, max(diabetes_values) + 5)


labels_hypertension = ['No Hipertensión', 'Hipertensión']
hypertension_values = [hypertension_count.get(0, 0), hypertension_count.get(1, 0)]

plt.subplot(1, 2, 2)
plt.bar(labels_hypertension, hypertension_values, color=['green', 'orange'])
plt.title('Hipertensión en Mujeres de 30 a 40 Años')
plt.ylabel('Cantidad')
plt.ylim(0, max(hypertension_values) + 5)

plt.tight_layout()
plt.show()

# %% [markdown]
# 17. Relación entre Diabetes, Hipertensión y Riesgo de Ataque al Corazón en Mujeres de 30 a 40 Años

# %%
plt.figure(figsize=(12, 6))

risk_counts = filt_df.groupby(['diabetes', 'hypertension', 'heart_risk']).size().unstack(fill_value=0)

risk_counts.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], edgecolor='black')

plt.title('Relación entre Diabetes, Hipertensión y Riesgo de Ataque al Corazón en Mujeres de 30 a 40 Años')
plt.xlabel('Diabetes y Hipertensión')
plt.ylabel('Cantidad de Mujeres')
plt.xticks(rotation=0)

plt.legend(title='Riesgo de Ataque al Corazón', labels=['No', 'Sí'])
plt.tight_layout()
plt.show()

# %% [markdown]
# # **7. Conclusiones y Trabajos Futuros**
#
# ## - Resumen del trabajo realizado, hallazgos y posibles mejoras
#
# Hay una alta complejidad de los factores que influyen en la salud cardiovascular. Es fundamental considerar otros enfoques analíticos y seguir investigando para obtener una comprensión más profunda.
#
# Tambien puede  ser que falto  una combinación de factores genéticos, y de estilo de vida. Es posible que las variables que he analizado no den el panorama completo de los riesgos asociados.
#
# Por ejemplo, la combinación de varios factores de riesgo (como fumar, diabetes, y nivel de actividad fisica) puede ser más relevante que cada uno por separado.
#
# Ademas que podria ser mas notorio si se usa un grupo de individuos con ciertar caracteristicas que de todos en general, ya que el dataset muestra datos muy similares entre sus variables.
