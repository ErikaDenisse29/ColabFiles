# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikaDenisse29/ColabFiles/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Práctica 2: Expresiones Regulares**
# El archivo contiene varios correos electrónicos en donde se informa el valor de las acciones de diferentes empresas. El código deberá extraer el valor actual de las acciones que aparecen en cada correo electrónico e imprimirlo a pantalla.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re

archivo = open('/content/drive/MyDrive/ClassFiles/informe_acciones.txt',encoding='latin-1')
print(archivo)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/ClassFiles/informe_acciones.txt' mode='r' encoding='latin-1'>

# %%
import re
archivo = open('/content/drive/MyDrive/ClassFiles/informe_acciones.txt',encoding='latin-1')
for linea in archivo:
    linea = linea.rstrip()
    if re.search('^Valor', linea):
        print(linea)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Valor actual: $248.63
# Valor actual: $1040.4
# Valor actual: $1069.26
# Valor actual: $1176.96
# Valor actual: $1388.71
# Valor actual: $556.6
# Valor actual: $1079.11
# Valor actual: $641.17
# Valor actual: $829.99
# Valor actual: $1183.61
# Valor actual: $1348.78
# Valor actual: $315.59
# Valor actual: $312.21
# Valor actual: $302.94
# Valor actual: $537.93
# Valor actual: $666.17
# Valor actual: $1485.45
# Valor actual: $380.7
# Valor actual: $758.83
# Valor actual: $108.43
# Valor actual: $830.68
# Valor actual: $1464.29
# Valor actual: $216.4
# Valor actual: $1449.27
# Valor actual: $328.62
# Valor actual: $222.71
# Valor actual: $1115.27
# Valor actual: $334.48
# Valor actual: $741.02
# Valor actual: $131.39
# Valor actual: $136.8
# Valor actual: $282.68
# Valor actual: $1481.37
# Valor actual: $762.07
# Valor actual: $620.05
# Valor actual: $1467.39
# Valor actual: $291.86
# Valor actual: $790.84
# ...
